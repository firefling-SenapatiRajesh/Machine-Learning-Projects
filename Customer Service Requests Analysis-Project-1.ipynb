# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
# %matplotlib inline

# %% [markdown]
# Task1-
# Understand the dataset:
# Identify the shape of the dataset,
# Identify variables with null values

# %%
df=pd.read_csv(r"C:\rajesh\python project excel\311_Service_Requests_from_2010_to_Present.csv",
               parse_dates=['Created Date','Closed Date'])
# Out:
# C:\Users\RajeshS\AppData\Local\Temp\ipykernel_4516\647325071.py:1: DtypeWarning: Columns (48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\rajesh\python project excel\311_Service_Requests_from_2010_to_Present.csv",

# %%
df.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %% [markdown]
# ## Identify the shape of the dataset

# %%
df.shape
# Out:
# (362177, 54)

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364558 entries, 0 to 364557
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      364558 non-null  int64
#  1   Created Date                    364558 non-null  datetime64[ns]
#  2   Closed Date                     362177 non-null  datetime64[ns]
#  3   Agency                          364558 non-null  object
#  4   Agency Name                     364558 non-null  object
#  5   Complaint Type                  364558 non-null  object
#  6   Descriptor                      358057 non-null  object
#  7   Location Type                   364425 non-null  object
#  8   Incident Zip                    361560 non-null  float64
#  9   Incident Address                312859 non-null  object
#  10  Street Name                     312859 non-null  object
# ...

# %% [markdown]
# # Identify variables with null values

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# School or Citywide Complaint      364558
# Vehicle Type                      364558
# Taxi Company Borough              364558
# Taxi Pick Up Location             364558
# Garage Lot Name                   364558
# Ferry Direction                   364557
# Ferry Terminal Name               364556
# Road Ramp                         364296
# Bridge Highway Segment            364296
# Bridge Highway Name               364261
# Bridge Highway Direction          364261
# Landmark                          364183
# Intersection Street 2             314046
# Intersection Street 1             313438
# Cross Street 2                     57805
# Cross Street 1                     57188
# Street Name                        51699
# Incident Address                   51699
# Descriptor                          6501
# X Coordinate (State Plane)          4030
# Latitude                            4030
# Longitude                           4030
# Y Coordinate (State Plane)          4030
# ...

# %%
df.columns=df.columns.str.replace(" ","_")

# %%
df
# Out:
#         Unique_Key        Created_Date         Closed_Date Agency  \
# 0         32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1         32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2         32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3         32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4         32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
# ...            ...                 ...                 ...    ...
# 364553    29609918 2015-01-01 00:04:00 2015-01-01 10:22:00   NYPD
# 364554    29608392 2015-01-01 00:04:00 2015-01-01 02:25:00   NYPD
# 364555    29607589 2015-01-01 00:01:00 2015-01-01 00:20:00   NYPD
# 364556    29610889 2015-01-01 00:01:00 2015-01-01 02:42:00   NYPD
# 364557    29611816 2015-01-01 00:00:00 2015-01-01 02:47:00   NYPD
#
#                             Agency_Name           Complaint_Type  \
# 0       New York City Police Department  Noise - Street/Sidewalk
# ...

# %%
sns.set()
df.isnull().sum().sort_values(ascending=True).plot(kind='barh',alpha=0.8,figsize=(18,15),title='Column wise Null value count')
plt.xlabel('Null Value Count')
plt.ylabel('Column Name')
plt.show()

# %%
df.columns
# Out:
# Index(['Unique_Key', 'Created_Date', 'Closed_Date', 'Agency', 'Agency_Name',
#        'Complaint_Type', 'Descriptor', 'Location_Type', 'Incident_Zip',
#        'Incident_Address', 'Street_Name', 'Cross_Street_1', 'Cross_Street_2',
#        'Intersection_Street_1', 'Intersection_Street_2', 'Address_Type',
#        'City', 'Landmark', 'Facility_Type', 'Status', 'Due_Date',
#        'Resolution_Description', 'Resolution_Action_Updated_Date',
#        'Community_Board', 'Borough', 'X_Coordinate_(State_Plane)',
#        'Y_Coordinate_(State_Plane)', 'Park_Facility_Name', 'Park_Borough',
#        'School_Name', 'School_Number', 'School_Region', 'School_Code',
#        'School_Phone_Number', 'School_Address', 'School_City', 'School_State',
#        'School_Zip', 'School_Not_Found', 'School_or_Citywide_Complaint',
#        'Vehicle_Type', 'Taxi_Company_Borough', 'Taxi_Pick_Up_Location',
#        'Bridge_Highway_Name', 'Bridge_Highway_Direction', 'Road_Ramp',
# ...

# %% [markdown]
# # Utilize missing value treatment

# %%
df['Closed_Date'].count()
# Out:
# 362177

# %%
df['Closed_Date'].isnull().sum()
# Out:
# 2381

# %%
df=df[pd.notnull(df['Closed_Date'])]

# %%
df['Closed_Date'].count()
# Out:
# 362177

# %%
df['Closed_Date'].isnull().sum()
# Out:
# 0

# %%
df[['Closed_Date','Created_Date']].isnull().sum()
# Out:
# Closed_Date     0
# Created_Date    0
# dtype: int64

# %% [markdown]
# ### Analyze the date column and remove the entries if it has an incorrect timeline

# %%
x=df.Created_Date[0]-df.Closed_Date[0]
x.seconds
# Out:
# 83085

# %%
df['Request_Closing_time']=df.Created_Date-df.Closed_Date
# Out:
# C:\Users\RajeshS\AppData\Local\Temp\ipykernel_4516\3691720344.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Request_Closing_time']=df.Created_Date-df.Closed_Date

# %%
import datetime
from datetime import date
df['Request_Closing_time']=df['Request_Closing_time']/np.timedelta64(1,'s')
# Out:
# C:\Users\RajeshS\AppData\Local\Temp\ipykernel_4516\164642610.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Request_Closing_time']=df['Request_Closing_time']/np.timedelta64(1,'s')

# %%
df['Request_Closing_time'].head()
# Out:
# 0    -3315.0
# 1    -5176.0
# 2   -17491.0
# 3   -27914.0
# 4   -12422.0
# Name: Request_Closing_time, dtype: float64

# %%
df['Request_Closing_time'].describe()
# Out:
# count    3.621770e+05
# mean    -1.511330e+04
# std      2.110251e+04
# min     -2.134342e+06
# 25%     -1.887900e+04
# 50%     -9.609000e+03
# 75%     -4.536000e+03
# max     -6.000000e+01
# Name: Request_Closing_time, dtype: float64

# %%
df['Request_Closing_time'].mean()
# Out:
# -15113.296310919799

# %%
df.columns
# Out:
# Index(['Unique_Key', 'Created_Date', 'Closed_Date', 'Agency', 'Agency_Name',
#        'Complaint_Type', 'Descriptor', 'Location_Type', 'Incident_Zip',
#        'Incident_Address', 'Street_Name', 'Cross_Street_1', 'Cross_Street_2',
#        'Intersection_Street_1', 'Intersection_Street_2', 'Address_Type',
#        'City', 'Landmark', 'Facility_Type', 'Status', 'Due_Date',
#        'Resolution_Description', 'Resolution_Action_Updated_Date',
#        'Community_Board', 'Borough', 'X_Coordinate_(State_Plane)',
#        'Y_Coordinate_(State_Plane)', 'Park_Facility_Name', 'Park_Borough',
#        'School_Name', 'School_Number', 'School_Region', 'School_Code',
#        'School_Phone_Number', 'School_Address', 'School_City', 'School_State',
#        'School_Zip', 'School_Not_Found', 'School_or_Citywide_Complaint',
#        'Vehicle_Type', 'Taxi_Company_Borough', 'Taxi_Pick_Up_Location',
#        'Bridge_Highway_Name', 'Bridge_Highway_Direction', 'Road_Ramp',
# ...

# %% [markdown]
# # Draw a frequency plot for city-wise complaints

# %%
df[['City','Complaint_Type']].isnull().sum()
# Out:
# City              674
# Complaint_Type      0
# dtype: int64

# %%
df['City'].fillna("Unknown City",inplace=True)
# Out:
# C:\Users\RajeshS\AppData\Local\Temp\ipykernel_4516\2787541958.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['City'].fillna("Unknown City",inplace=True)

# %%
df[['City','Complaint_Type']].isnull().sum()
# Out:
# City              0
# Complaint_Type    0
# dtype: int64

# %%
df['City'].value_counts().sort_values(ascending=True).plot(kind='barh',figsize=(18,16),title='City-wise customer complaints')
plt.xlabel('Complaint Count')
plt.ylabel('City')
plt.show()

# %% [markdown]
# #Brooklyn stands at 1st,then New york & bronx are standing in next places for
# #having most number of complaints

# %% [markdown]
# # Draw scatter and hexbin plots for complaint concentration across Brooklyn

# %%
brooklyn_complaints=df[df['City']=='BROOKLYN']

# %%
brooklyn_complaints.plot(kind='scatter',x='Longitude',y='Latitude',figsize=(8,8)
                                                  ,title='Complaints Concentration Across Brooklyn').axis('equal')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
brooklyn_complaints.plot(kind='hexbin',x='Longitude',y='Latitude',gridsize=40,
                         colormap='jet',mincnt=1,title='Complaints Concentration Across Brooklyn',
                         figsize=(10,10)).axis('equal')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# #Hexbin is giving better results than scatter
# #Concentration found more in the Top side towards left side of the map

# %%
brok=brooklyn_complaints.reset_index()
brok['Complaint_Type'].value_counts().plot(kind='bar',figsize=(10,10),title='Brooklyn complaints count')
plt.xlabel('Brooklyn complaints')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #Blocked driveway complaint is leading in Brooklyn city,where Illegal parking and Noise-Street/Sidewalk are next most

# %% [markdown]
# # Plot a bar graph of count vs. complaint types

# %%
sns.set()
df['Complaint_Type'].value_counts().plot(kind='bar',figsize=(16,12),title='Count of each complaint type')
plt.xlabel('Complaint type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Blocked driveway complaint is leading for all cities as well,where Illegal parking and Noise-Street/Sidewalk are next most

# %%
df.loc[df['City']=='NEW YORK']['Complaint_Type'].value_counts().plot(kind='bar',figsize=(10,10),title='Newyork complaint')
# Out:
# <AxesSubplot:title={'center':'Newyork complaint'}>

# %% [markdown]
# # Find the top 10 types of complaints

# %%
df['Complaint_Type'].value_counts()[0:10]
# Out:
# Blocked Driveway           100624
# Illegal Parking             91716
# Noise - Street/Sidewalk     51139
# Noise - Commercial          43751
# Derelict Vehicle            21518
# Noise - Vehicle             19301
# Animal Abuse                10530
# Traffic                      5196
# Homeless Encampment          4879
# Vending                      4185
# Name: Complaint_Type, dtype: int64

# %%
top_10_complaints=np.array(df['Complaint_Type'].value_counts()[0:10].index)
top_10_complaints
# Out:
# array(['Blocked Driveway', 'Illegal Parking', 'Noise - Street/Sidewalk',
#        'Noise - Commercial', 'Derelict Vehicle', 'Noise - Vehicle',
#        'Animal Abuse', 'Traffic', 'Homeless Encampment', 'Vending'],
#       dtype=object)

# %% [markdown]
# # Display the types of complaints in each city in a separate dataset

# %%
df_new=pd.DataFrame()

# %%
for i in df['City'].unique():
    df_new[i]=df.loc[df['City']==i]['Complaint_Type'].value_counts()

# %%
df_new
# Out:
#                            NEW YORK  ASTORIA    BRONX  ELMHURST  BROOKLYN  \
# Noise - Street/Sidewalk       22245    409.0   9144.0     228.0   13982.0
# Noise - Commercial            18686   1653.0   2944.0      85.0   13855.0
# Illegal Parking               14549   1340.0   9889.0     760.0   33532.0
# Noise - Vehicle                6294    236.0   3556.0      69.0    5965.0
# Homeless Encampment            3060     32.0    275.0      34.0     948.0
# Blocked Driveway               2705   3436.0  17062.0    1992.0   36445.0
# Vending                        2638     57.0    433.0      25.0     575.0
# Animal Abuse                   1941    170.0   1971.0      59.0    3191.0
# Traffic                        1769     60.0    427.0      18.0    1258.0
# Noise - Park                   1243     64.0    548.0      35.0    1575.0
# Derelict Vehicle                695    426.0   2402.0      94.0    6257.0
# Drinking                        321     43.0    206.0      13.0     291.0
# ...

# %%
df_new['NEW YORK'].plot(kind='barh',figsize=(15,15),title='Complaints')
plt.show()

# %%
sns.set()
df_new.T.plot(kind='barh',stacked=True,figsize=(20,36),title='City-wise customer complaints')
plt.xlabel('Complaint count')
plt.ylabel('City')
plt.show()

# %% [markdown]
# #Noise issues are more in New york city(both commercial and street)

# %% [markdown]
# # Visualize the major types of complaints in each city

# %%
df_new_T=df_new.T
df_new_T
# Out:
#                      Noise - Street/Sidewalk  Noise - Commercial  \
# NEW YORK                             22245.0             18686.0
# ASTORIA                                409.0              1653.0
# BRONX                                 9144.0              2944.0
# ELMHURST                               228.0                85.0
# BROOKLYN                             13982.0             13855.0
# KEW GARDENS                             13.0               203.0
# JACKSON HEIGHTS                        238.0               619.0
# MIDDLE VILLAGE                          38.0                13.0
# REGO PARK                               64.0                82.0
# SAINT ALBANS                            81.0                36.0
# JAMAICA                                365.0               552.0
# SOUTH RICHMOND HILL                     93.0               223.0
# Unknown City                            99.0                79.0
# ...

# %%
sns.set()
f,ax=plt.subplots(figsize=(20,30))
sns.heatmap(df_new_T[top_10_complaints],annot=True,cbar=False,linewidths=.8,ax=ax)
plt.show()

# %% [markdown]
# # Check if the average response time across various types of complaints is same

# %%
df.columns
# Out:
# Index(['Unique_Key', 'Created_Date', 'Closed_Date', 'Agency', 'Agency_Name',
#        'Complaint_Type', 'Descriptor', 'Location_Type', 'Incident_Zip',
#        'Incident_Address', 'Street_Name', 'Cross_Street_1', 'Cross_Street_2',
#        'Intersection_Street_1', 'Intersection_Street_2', 'Address_Type',
#        'City', 'Landmark', 'Facility_Type', 'Status', 'Due_Date',
#        'Resolution_Description', 'Resolution_Action_Updated_Date',
#        'Community_Board', 'Borough', 'X_Coordinate_(State_Plane)',
#        'Y_Coordinate_(State_Plane)', 'Park_Facility_Name', 'Park_Borough',
#        'School_Name', 'School_Number', 'School_Region', 'School_Code',
#        'School_Phone_Number', 'School_Address', 'School_City', 'School_State',
#        'School_Zip', 'School_Not_Found', 'School_or_Citywide_Complaint',
#        'Vehicle_Type', 'Taxi_Company_Borough', 'Taxi_Pick_Up_Location',
#        'Bridge_Highway_Name', 'Bridge_Highway_Direction', 'Road_Ramp',
# ...

# %%
df.groupby(['City','Complaint_Type'],sort=True).Request_Closing_time.mean()
# Out:
# City      Complaint_Type
# ARVERNE   Animal Abuse               -8399.608696
#           Blocked Driveway           -8320.020000
#           Derelict Vehicle          -11391.687500
#           Disorderly Youth          -12928.500000
#           Drinking                    -859.000000
#                                          ...
# Woodside  Blocked Driveway          -15565.111111
#           Derelict Vehicle          -19990.625000
#           Illegal Parking           -17295.314516
#           Noise - Commercial         -8619.000000
#           Noise - Street/Sidewalk   -12280.600000
# Name: Request_Closing_time, Length: 792, dtype: float64

# %%
df.Request_Closing_time.describe()
# Out:
# count    3.621770e+05
# mean    -1.511330e+04
# std      2.110251e+04
# min     -2.134342e+06
# 25%     -1.887900e+04
# 50%     -9.609000e+03
# 75%     -4.536000e+03
# max     -6.000000e+01
# Name: Request_Closing_time, dtype: float64

# %%
sns.set()
sns.distplot(df.Request_Closing_time,hist=False)
plt.show()
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
df.groupby(['Complaint_Type'],sort=True).Request_Closing_time.mean()
# Out:
# Complaint_Type
# Agency Issues               -1.829512e+04
# Animal Abuse                -1.803257e+04
# Animal in a Park            -1.212605e+06
# Bike/Roller/Skate Chronic   -1.312373e+04
# Blocked Driveway            -1.623243e+04
# Derelict Vehicle            -2.535961e+04
# Disorderly Youth            -1.236330e+04
# Drinking                    -1.382040e+04
# Graffiti                    -2.327552e+04
# Homeless Encampment         -1.545133e+04
# Illegal Fireworks           -1.011255e+04
# Illegal Parking             -1.565054e+04
# Noise - Commercial          -1.108576e+04
# Noise - House of Worship    -1.139122e+04
# Noise - Park                -1.222613e+04
# Noise - Street/Sidewalk     -1.223129e+04
# Noise - Vehicle             -1.256187e+04
# Panhandling                 -1.585314e+04
# Posting Advertisement       -7.285103e+03
# Squeegee                    -1.456425e+04
# Traffic                     -1.230899e+04
# Urinating in Public         -1.295872e+04
# ...

# %%
df.Request_Closing_time.describe()
# Out:
# count    3.621770e+05
# mean    -1.511330e+04
# std      2.110251e+04
# min     -2.134342e+06
# 25%     -1.887900e+04
# 50%     -9.609000e+03
# 75%     -4.536000e+03
# max     -6.000000e+01
# Name: Request_Closing_time, dtype: float64

# %% [markdown]
# #Time taken for Posting advertisement,Animal in a park complaints colsing time is different

# %%
sns.distplot(df.Request_Closing_time,hist=False)
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Request_Closing_time', ylabel='Density'>

# %% [markdown]
# # Identify significant variables by performing a statistical analysis using p-values and chi-square values

# %%
from scipy.stats import shapiro
stat,p=shapiro(df.Request_Closing_time)
print(stat,p)
# Out:
# 0.5137225389480591 0.0
# C:\anaconda\lib\site-packages\scipy\stats\morestats.py:1760: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %% [markdown]
# #P value (0.0) returned is less than 0.05, then the null hypothesis is rejected and there is evidence that the data is not from a normally distributed population

# %%
import statsmodels.api as sm
import pylab
sm.qqplot(df.Request_Closing_time,loc=4,scale=3,line='s')
pylab.show()

# %% [markdown]
# Kruskal Wallis H Test
# #Fail to Reject H0: All sample distributions are equal.
# #Reject H0: One or more sample distributions are not equal.

# %%
Complaint_types=df.Complaint_Type.unique()

# %%
len(Complaint_types)
# Out:
# 23

# %%
new=[]
for i in Complaint_types:
    new.append(df.loc[df['Complaint_Type']==i]['Request_Closing_time'].ravel())

# %%
new[1]
# Out:
# array([ -5176., -17491.,  -6475., ..., -21540.,  -9660., -10020.])

# %%
from scipy.stats import kruskal
stat, p = kruskal(new[0],new[1], new[2],new[3], new[4], new[5], new[6], new[7], new[8], new[9], new[10], new[11], new[12], new[13])
print('Statistics=%.3f, p=%.3f' % (stat, p))
alpha = 0.05
if p > alpha:
    print('Same distributions (fail to reject H0)')
else:
    print('Different distributions (reject H0)')
# Out:
# Statistics=11743.557, p=0.000
# Different distributions (reject H0)

# %% [markdown]
# #So, we reject the H0, that means average response time across complaint types are not similar
